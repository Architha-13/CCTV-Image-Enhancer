# %%
import numpy as np
import cv2

img = cv2.imread("C:/Users/archi/Downloads/enhanced.png")

# Get image shape
print(img.shape)

# Loop through pixels
for y in range(img.shape[0]):
    for x in range(img.shape[1]):
        pixel = img[y, x]
# Out:
# (2436, 1748, 3)

# %%
import numpy as np
import cv2

img = cv2.imread("C:/Users/archi/OneDrive/Pictures/Screenshots/Screenshot 2025-02-11 211409.png")

# Get image shape
print(img.shape)

# Loop through pixels
for y in range(img.shape[0]):
    for x in range(img.shape[1]):
        pixel = img[y, x]
# Out:
# (609, 437, 3)
